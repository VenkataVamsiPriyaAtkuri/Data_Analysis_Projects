# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import scipy as s
import scipy.stats as ss

# %%
df = pd.read_csv(r"C:\Users\priya\Downloads\autos.csv", encoding='latin-1')

# %%
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
# ...

# %%
df[['abtest','fuelType','model','gearbox','vehicleType','notRepairedDamage']].mode()
# Out:
#   abtest fuelType model  gearbox vehicleType notRepairedDamage
# 0   test   benzin  golf  manuell   limousine              nein

# %%
df[['price','yearOfRegistration','powerPS','monthOfRegistration','kilometer','nrOfPictures','postalCode']].mean()
# Out:
# price                   17295.141865
# yearOfRegistration       2004.577997
# powerPS                   115.549477
# monthOfRegistration         5.734445
# kilometer              125618.688228
# nrOfPictures                0.000000
# postalCode              50820.667640
# dtype: float64

# %%
df.replace({'abtest':{np.nan:'test'},'fuelType':{np.nan:'benzin'},'model':{np.nan:'golf'},'gearbox':{np.nan:'manuell'},'vehicleType':{np.nan:'limousine'},'notRepairedDamage':{np.nan:'nein'}},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          371528 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              371528 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                371528 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             371528 non-null  object
#  14  brand                371528 non-null  object
# ...

# %% [markdown]
# ### Can you tell me the Distribution of Vehicles based on Year of Registration with the help of a plot

# %%
df["yearOfRegistration"] = df["yearOfRegistration"].where((df["yearOfRegistration"] >= 1950) & (df["yearOfRegistration"] <= 2023),df["yearOfRegistration"].mode()[0])
plt.figure(figsize=(15, 10))
sns.histplot(df, x=df["yearOfRegistration"])
plt.axvline(df['yearOfRegistration'].mean(),color='g',linestyle='--')
plt.axvline(df['yearOfRegistration'].median(),color='k',linestyle=':')
plt.title("Distribution of Vehicles by Year of Registration")
plt.show()

# %% [markdown]
# ### Create a plot based on the Variation of the price range by the vehicle type

# %%
average_prices_by_type=df.groupby('vehicleType')['price'].mean()
average_prices_by_type=average_prices_by_type.sort_values()
sns.barplot(x=average_prices_by_type.index, y=average_prices_by_type.values)
plt.xlabel('Vehicle Type')
plt.ylabel('Average Price')
plt.title('Average Price by Vehicle Type')
plt.show()

# %% [markdown]
# ### Find out Total count of vehicles by type available on ebay for sale.As well as create a visualization for the client

# %%
vehicle_count_by_type=df['vehicleType'].value_counts()
plt.figure(figsize=(10,12))
sns.barplot(x=vehicle_count_by_type.index, y=vehicle_count_by_type.values)
plt.xlabel('Vehicle Type')
plt.ylabel('Total Count')
plt.title('Total Count of Vehicles by Type')
plt.show()

# %% [markdown]
# ###  Is there any relationship between dollar_price and kilometer?

# %%
df[['price','kilometer']].corr(method='spearman')
# Out:
#               price  kilometer
# price      1.000000  -0.373047
# kilometer -0.373047   1.000000

# %%
sns.scatterplot(data=df, x='kilometer', y='price')
plt.title('Relationship between Price and Kilometer')
plt.tight_layout()
plt.show()
